# %% [markdown]
# # 📊E-commerce Customer Behavior Dataset

# %% [markdown]
# ## About Dataset

# %% [markdown]
# This dataset captures detailed information about customer behavior and purchasing patterns, primarily from an e-commerce or retail platform. It includes various features that help in analyzing how customers interact with the site, their purchasing habits, and some demographic details.

# %% [markdown]
# ## Key Variables and Descriptions

# %% [markdown]
# #### Customer ID:-
# A unique identifier assigned to each customer. This attribute is essential for tracking individual customer behavior across different features in the dataset.
#
# #### Age:-
# Records the age of each customer. This attribute is useful for demographic analysis, helping to identify age-related trends and preferences in purchasing behavior.
#
# #### Gender:-
# Indicates the gender of each customer (e.g., Male, Female). Analyzing this attribute allows for understanding gender-specific trends in product preferences and purchasing habits.
#
# #### Location:-
# Represents the geographic location of the customer. This attribute helps in identifying regional trends and differences in customer behavior, which can inform location-based marketing strategies.
#
# #### Annual Income:-
# Reflects the annual income of the customer. This financial attribute is critical for segmenting customers by their purchasing power and understanding the relationship between income levels and buying patterns.
#
# #### Purchase History:-
# A list of products that each customer has purchased, including details such as the purchase date, product category, and price. It provides insights into customer preferences and helps in analyzing repeat purchases and category-specific trends.
#
# #### Browsing History:-
# A log of products viewed by each customer, along with timestamps. This attribute is important for understanding customer interest and engagement, even if a purchase was not made.
#
# #### Product Reviews:-
# Contains text reviews written by customers about products they have purchased, along with a rating (1-5 stars). This attribute provides qualitative insights into customer satisfaction and product quality.
#
# #### Time on Site:-
# Measures the total time a customer spends on the platform during their visit. It is a key metric for analyzing user engagement and can be correlated with browsing and purchasing behavior.

# %% [markdown]
# ##  1. Importing Dataset and Pequired Packages

# %%
import numpy as nm
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("e-commerce dataset.csv")

df
# Out:
#     Customer ID  Age  Gender Location  Annual Income  \
# 0          1001   25  Female   City D          45000
# 1          1001   28  Female   City D          52000
# 2          1001   28  Female   City D          65000
# 3          1001   45  Female   City D          70000
# 4          1002   34    Male   City E          45000
# 5          1003   56   Other   City F          90000
# 6          1004   29  Female   City G          60000
# 7          1005   42    Male   City H          75000
# 8          1006   51   Other   City I          85000
# 9          1007   36  Female   City J          55000
# 10         1008   48    Male   City K          80000
# 11         1009   25   Other   City L          40000
# 12         1001   45  Female   City D          75000
# 13         1002   32    Male   City A          50000
# 14         1003   60   Other   City B          80000
# 15         1004   28  Female   City C          45000
# 16         1005   55    Male   City E          90000
# ...

# %%
df.shape
# Out:
# (50, 9)

# %%
df.head()
# Out:
#    Customer ID  Age  Gender Location  Annual Income  \
# 0         1001   25  Female   City D          45000
# 1         1001   28  Female   City D          52000
# 2         1001   28  Female   City D          65000
# 3         1001   45  Female   City D          70000
# 4         1002   34    Male   City E          45000
#
#                                     Purchase History  \
# 0  [{"Date": "2022-03-05", "Category": "Clothing"...
# 1  [{"Product Category": "Clothing", "Purchase Da...
# 2  [{"Product Category": "Electronics", "Purchase...
# 3  {'Purchase Date': '2022-08-15', 'Product Categ...
# 4  {'Purchase Date': '2022-07-25', 'Product Categ...
#
#                                     Browsing History  \
# 0  [{"Timestamp": "2022-03-10T14:30:00Z"}, {"Time...
# 1  [{"Product Category": "Home & Garden", "Timest...
# 2  [{"Product Category": "Clothing", "Timestamp":...
# 3               {'Timestamp': '2022-09-03 14:30:00'}
# 4               {'Timestamp': '2022-08-10 17:15:00'}
#
# ...

# %%
df.tail()
# Out:
#     Customer ID  Age  Gender Location  Annual Income  \
# 45         1004   52  Female   City G         100000
# 46         1005   24    Male   City H          45000
# 47         1001   34  Female   City D          55000
# 48         1002   45    Male   City E          87000
# 49         1003   29   Other   City F          42000
#
#                                      Purchase History  \
# 45  [{"Product Category": "Clothing", "Purchase Da...
# 46  [{"Product Category": "Electronics", "Purchase...
# 47  [{"Purchase Date": "2022-07-02","Product Categ...
# 48  [{"Purchase Date": "2022-07-08","Product Categ...
# 49  [{"Purchase Date": "2022-07-01","Product Categ...
#
#                                      Browsing History  \
# 45  [{"Product Category": "Electronics", "Timestam...
# 46  [{"Product Category": "Clothing", "Timestamp":...
# 47  [{"Timestamp": "2022-08-14T09:30:00Z"},{"Times...
# 48  [{"Timestamp": "2022-08-12T16:00:00Z"},{"Times...
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID         0
# Age                 0
# Gender              0
# Location            0
# Annual Income       0
# Purchase History    0
# Browsing History    0
# Product Reviews     0
# Time on Site        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no duplicate value

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Customer ID       50 non-null     int64
#  1   Age               50 non-null     int64
#  2   Gender            50 non-null     object
#  3   Location          50 non-null     object
#  4   Annual Income     50 non-null     int64
#  5   Purchase History  50 non-null     object
#  6   Browsing History  50 non-null     object
#  7   Product Reviews   50 non-null     object
#  8   Time on Site      50 non-null     float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 3.6+ KB

# %%
df.nunique()
# Out:
# Customer ID         13
# Age                 22
# Gender               3
# Location            16
# Annual Income       17
# Purchase History    50
# Browsing History    50
# Product Reviews     47
# Time on Site        32
# dtype: int64

# %%
df.describe()
# Out:
#        Customer ID        Age  Annual Income  Time on Site
# count    50.000000  50.000000      50.000000     50.000000
# mean   1004.880000  39.960000   65780.000000    232.597000
# std       3.623281  11.067437   17059.667198    109.669736
# min    1001.000000  24.000000   40000.000000     32.500000
# 25%    1002.000000  30.250000   50500.000000    124.100000
# 50%    1004.000000  37.000000   65000.000000    243.450000
# 75%    1007.750000  48.000000   80000.000000    300.000000
# max    1013.000000  65.000000  100000.000000    486.300000

# %%
df.dtypes
# Out:
# Customer ID           int64
# Age                   int64
# Gender               object
# Location             object
# Annual Income         int64
# Purchase History     object
# Browsing History     object
# Product Reviews      object
# Time on Site        float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Location', 'Annual Income',
#        'Purchase History', 'Browsing History', 'Product Reviews',
#        'Time on Site'],
#       dtype='object')

# %%
numerical_columns=[col for col in df.columns if df[col].dtypes!='object']
cat_columns=[col for col in df.columns if df[col].dtypes=='object']
print("There is total {} numerical columns as: {}".format(len(numerical_columns),numerical_columns))
print("There is total {} categorical columns as: {}".format(len(cat_columns),cat_columns))
# Out:
# There is total 4 numerical columns as: ['Customer ID', 'Age', 'Annual Income', 'Time on Site']
# There is total 5 categorical columns as: ['Gender', 'Location', 'Purchase History', 'Browsing History', 'Product Reviews']

# %% [markdown]
# # 2. Exploring Data

# %% [markdown]
# ## 2.1.1. Univariate Analysis(Numerical)

# %%
sns.histplot(df['Annual Income'],kde=True)
plt.show()

# %%
sns.set_style('whitegrid')
sns.FacetGrid(df,hue='Age',height=5).map(sns.histplot,'Time on Site',kde=True).add_legend()
plt.show()

# %% [markdown]
# ### Conclusion:- Histplot show that older Age coustomers spend more time on the Site.

# %% [markdown]
# ## 2.1.2. Univariate Analysis(Categorical)

# %%
print(df['Product Reviews'].value_counts())
# Out:
# {"Review Text": "Excellent product, highly recommend!", "Rating": 5}                                                             3
# {"Product 1": {"Rating": 4, "Review": "Great product, will definitely buy again."}}                                              2
# Great pair of jeans, very comfortable. Rating: 4 stars.                                                                          1
# Great find! 5 stars                                                                                                              1
# The phone is fantastic. 5 stars!                                                                                                 1
# The shirt is comfortable. 4 stars.                                                                                               1
# The laptop is excellent. 5 stars!                                                                                                1
# ...

# %%
sns.countplot(data=df,x='Product Reviews')
plt.show()

# %%
sns.countplot(data=df,x='Gender')
plt.show()

# %% [markdown]
# ### Conclusion:- Countplot shows that they have high number of female coustomer than men

# %% [markdown]
# ## 2.2.1. Bivariate analysis(Numerical-Numerical)

# %%
sns.scatterplot(data=df,x='Annual Income',y='Time on Site')
plt.show()

# %%
sns.jointplot(x='Annual Income', y='Age', data=df, kind='scatter')
plt.show()

# %% [markdown]
# ### Conclusion:- jointplot is showing that The old Age coustomer has the High Annual Income as they have high experience in their respected profession.

# %% [markdown]
# ## 2.2.2. Bivariate analysis(Numerical-Categorical)

# %% [markdown]
# ## 1. BoxPlot

# %%
sns.boxplot(data=df,x='Gender',y='Annual Income')
plt.title("Gender vs Annual Income")
plt.show()

# %% [markdown]
# ## 2. ViolinPlot

# %%
sns.violinplot(data=df,x='Gender',y='Annual Income')
plt.title("Gender vs Annual Income")
plt.show()

# %% [markdown]
# ## 3. BarPlot

# %%
sns.barplot(data=df,x='Gender',y='Annual Income')
plt.title("Gender vs Annual Income")
plt.show()

# %% [markdown]
# ### Conclusion:- Here we can clearly see through these plots that the avg Income of a Male Coustomer is generaly higher i.e. (mean-75,000) than a Female coustomer i.e. (mean 60,000)

# %% [markdown]
# ## 4. Annova

# %%
from scipy import stats
anova_result = stats.f_oneway(df[df['Gender'] == 'Male']['Annual Income'],
                              df[df['Gender'] == 'Female']['Annual Income'],
                              df[df['Gender'] == 'Other']['Annual Income'])
anova_result
# Out:
# F_onewayResult(statistic=1.6733150935056005, pvalue=0.19860724353321033)

# %% [markdown]
# # 2.3.1 MultiVariate Analysis:-

# %%
sns.pairplot(df,hue='Gender')
plt.show()

# %% [markdown]
# ## conclusion:- Here we can see that Male has more Annual Income than Female as we saw earlier , so they spend more time on the site thanthe female coustomer
